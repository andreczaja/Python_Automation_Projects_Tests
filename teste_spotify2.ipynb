# %%
import pandas as pd
tabela = pd.read_csv('spotifydataset.csv')

# %%
tabela
# Out:
#      Unnamed: 0    artist_name  \
# 0             0  Ariana Grande
# 1             1  Ariana Grande
# 2             2  Ariana Grande
# 3             3  Ariana Grande
# 4             4  Ariana Grande
# ..          ...            ...
# 995         995        Outkast
# 996         996        Outkast
# 997         997        Outkast
# 998         998        Outkast
# 999         999        Outkast
#
#                                                 genres  followers  \
# 0                                                  pop   98934105
# 1                                                  pop   98934105
# 2                                                  pop   98934105
# 3                                                  pop   98934105
# 4                                                  pop   98934105
# ..                                                 ...        ...
# 995  atl hip hop, dirty south rap, hip hop, old sch...    2769972
# ...

# %%
tabela2 = tabela[(tabela['loudness'] < -6) & (tabela['loudness'] > -8)]

# %%
tabela3 = pd.DataFrame(tabela2.groupby('artist_name')['artist_name'].count())
tabela3.index.name = "index_artist"
tabela3
# Out:
#                         artist_name
# index_artist
# A                                12
# A Boogie Wit da Hoodie            4
# A Day To Remember                 1
# A$AP Ferg                         2
# A$AP Rocky                        4
# ...                             ...
# Young Thug                        3
# aespa                             1
# Â                                 2
# Ã                                 1
# Å                                 2
#
# [76 rows x 1 columns]

# %%
tabela3.sort_values(by='artist_name',ascending=False)
# Out:
#                           artist_name
# index_artist
# A                                  12
# Arijit Singh                        7
# Alex Warren                         6
# Alice In Chains                     6
# Halsey                              6
# ...                               ...
# Novo Amor                           1
# The Alchemist                       1
# The All-American Rejects            1
# aespa                               1
# Ã                                   1
#
# [76 rows x 1 columns]
